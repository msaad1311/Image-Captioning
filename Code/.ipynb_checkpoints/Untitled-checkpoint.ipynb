# %%
import pandas as pd
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# import tensorflow as tf
# from tensorflow import keras
from tensorflow.keras.layers import *

# %%
path = r'/Users/saad/Desktop/Image-Captioning/Train/Data'
caption = 'captions.csv'

# %%
df = pd.read_csv(os.path.join(path,caption),delimiter='|')
df.head(10)
# Out:
#        image_name   comment_number  \
# 0  1000092795.jpg                0
# 1  1000092795.jpg                1
# 2  1000092795.jpg                2
# 3  1000092795.jpg                3
# 4  1000092795.jpg                4
# 5    10002456.jpg                0
# 6    10002456.jpg                1
# 7    10002456.jpg                2
# 8    10002456.jpg                3
# 9    10002456.jpg                4
#
#                                              comment
# 0   Two young guys with shaggy hair look at their...
# 1   Two young , White males are outside near many...
# 2   Two men in green shirts are standing in a yard .
# 3       A man in a blue shirt standing in a garden .
# 4            Two friends enjoy time spent together .
# 5   Several men in hard hats are operating a gian...
# 6   Workers look down from up above on a piece of...
# 7   Two men working on a machine wearing hard hats .
# 8              Four men on top of a tall structure .
# 9                         Three men on a large rig .

# %%
def image_read(path):
    old = os.getcwd()
    images=[]
    names=[]
    for i in os.listdir(path):
#         print(i)
        images.append(cv2.resize(cv2.imread(os.path.join(path,i)),(240,240)))
        names.append(i)
    return np.array(images),names

# %%
images,names = image_read(os.path.join(path,'images'))

# %%
images.shape
# Out:
# (30, 240, 240, 3)

# %%
plt.imshow(images[1])

# %%
names[1]
# Out:
# '1000344755.jpg'

# %%
import math
math.sqrt(2048)
# Out:
# 45.254833995939045

# %%
from tensorflow.keras.applications import ResNet50
model=ResNet50(include_top=False,weights="imagenet",input_shape=(240,240,3),pooling='avg')

# %%
preds = model.predict(images)

# %%
preds.shape
# Out:
# (30, 2048)

# %%
df.head()
# Out:
#        image_name   comment_number  \
# 0  1000092795.jpg                0
# 1  1000092795.jpg                1
# 2  1000092795.jpg                2
# 3  1000092795.jpg                3
# 4  1000092795.jpg                4
#
#                                              comment
# 0   Two young guys with shaggy hair look at their...
# 1   Two young , White males are outside near many...
# 2   Two men in green shirts are standing in a yard .
# 3       A man in a blue shirt standing in a garden .
# 4            Two friends enjoy time spent together .

# %%
df_caption = df[df[' comment_number']==0].reset_index(drop=True)
df_caption[' comment'] = df_caption[' comment'].str.rstrip()
df_caption[' comment']=df_caption[' comment'].str.lstrip()
df_caption.head()
# Out:
#        image_name   comment_number  \
# 0  1000092795.jpg                0
# 1    10002456.jpg                0
# 2  1000268201.jpg                0
# 3  1000344755.jpg                0
# 4  1000366164.jpg                0
#
#                                              comment
# 0  Two young guys with shaggy hair look at their ...
# 1  Several men in hard hats are operating a giant...
# 2  A child in a pink dress is climbing up a set o...
# 3  Someone in a blue shirt and hat is standing on...
# 4  Two men , one in a gray shirt , one in a black...

# %%
df_names = pd.DataFrame(names,columns=['image_name'])
df_combined = df_names.merge(df_caption,on='image_name',how='left')
df_combined['tokens']=['<START> ']+df_combined[' comment'] + [' <END>']
df_combined.head()
# Out:
#        image_name   comment_number  \
# 0   100577935.jpg                0
# 1  1000344755.jpg                0
# 2    10002456.jpg                0
# 3    10010052.jpg                0
# 4  1003163366.jpg                0
#
#                                              comment  \
# 0  A man with a goatee in a black shirt and white...
# 1  Someone in a blue shirt and hat is standing on...
# 2  Several men in hard hats are operating a giant...
# 3  A girl is on rollerskates talking on her cellp...
# 4  a man sleeping on a bench outside with a white...
#
#                                               tokens
# 0  <START> A man with a goatee in a black shirt a...
# 1  <START> Someone in a blue shirt and hat is sta...
# 2  <START> Several men in hard hats are operating...
# 3  <START> A girl is on rollerskates talking on h...
# 4  <START> a man sleeping on a bench outside with...

# %%
captions = df_combined['tokens'].tolist()
len(captions)
# Out:
# 30

# %%
captions[0]
# Out:
# "<START> A man with a goatee in a black shirt and white latex gloves is using a tattoo gun to place a tattoo on someone 's back . <END>"
